# %%
with open('out.txt') as f:
    content = f.read()

# %%
num = content.split('\n')
# num = list(map(lambda x: float(x),num))
num
# Out:
# ['2.0',
#  '2.0',
#  '1.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '1.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '1.0',
#  '1.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
#  '2.7',
#  '2.5909090909090913',
#  '3.0',
#  '3.0',
#  '3.0',
#  '3.0',
# ...
